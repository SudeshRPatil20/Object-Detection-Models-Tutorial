# %% [markdown]
# <a href="https://colab.research.google.com/github/SudeshRPatil20/Object-Detection-Models-Tutorial/blob/main/yolo11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.1/112.6 GB disk)

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.1/112.6 GB disk)

# %% [markdown]
# # New Section

# %%
# %cd /content/drive/MyDrive/x_ray_detection
# Out:
# /content/drive/MyDrive/x_ray detection

# %%
# !unzip /content/drive/MyDrive/x_ray_detection/X_ray
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/3182_png_jpg.rf.d8143769977f4073ffcde688375e6f9f.txt
#   inflating: train/labels/3182_png_jpg.rf.e2fd899dea9293a28bb06fab3ae7be26.txt
#   inflating: train/labels/3183_png_jpg.rf.31b97bfe09e2b6d177ccb0954e9e8d7a.txt
#   inflating: train/labels/3183_png_jpg.rf.e8355d2b5db3bae453603b7819492f92.txt
#   inflating: train/labels/3184_png_jpg.rf.5ede57c83d3b8a9fc026b9a847abc759.txt
#   inflating: train/labels/3184_png_jpg.rf.ce58ea0235979ee402209757e741e422.txt
#   inflating: train/labels/3185_png_jpg.rf.a8bec410d26394a47c4a92595de2ac5c.txt
#   inflating: train/labels/3185_png_jpg.rf.b95e1fc571500cf03f6cf33c083b4df0.txt
#   inflating: train/labels/3185_png_jpg.rf.f7986177ab2862245e01868eee07bf49.txt
#   inflating: train/labels/3186_png_jpg.rf.2977c97a7289a3d40f3502d50d4bd93f.txt
#   inflating: train/labels/3186_png_jpg.rf.3429278b5324015a62a1ddb08c0d8f71.txt
# ...

# %%
# !yolo train model=yolo11m.pt data="/content/drive/MyDrive/x_ray_detection/data.yaml" epochs=2 imgsz=640
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo val model="/content/drive/MyDrive/x_ray_detection/runs/detect/train2/weights/best.pt" data="/content/drive/MyDrive/x_ray_detection/data.yaml"
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,034,658 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 11.2±3.8 MB/s, size: 27.6 KB)
# val: Scanning /content/drive/MyDrive/x_ray_detection/valid/labels.cache... 387 images, 0 backgrounds, 0 corrupt: 100% 387/387 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:13<00:00,  1.89it/s]
#                    all        387       6564      0.994      0.992      0.993      0.736
#                    DIP        387       1541      0.996      0.995      0.994      0.713
#                    MCP        387       1932      0.994      0.998      0.994      0.745
#                    PIP        387       1934      0.997      0.996      0.994       0.74
#                 Radius        385        385      0.987      0.992      0.993      0.726
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

def image_show(img_path):
    image = cv2.imread(img_path)
    if image is None:
        print("Error: Image not found!")
        return

    cv2_imshow(image)

# %%
! yolo predict model="/content/drive/MyDrive/x_ray_detection/runs/detect/train2/weights/best.pt" source="/content/drive/MyDrive/x_ray_detection/train/images/1377_png_jpg.rf.7f7819891391b7db39229dd3724786df.jpg"
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,034,658 parameters, 0 gradients, 67.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/x_ray_detection/train/images/1377_png_jpg.rf.7f7819891391b7db39229dd3724786df.jpg: 640x640 4 DIPs, 5 MCPs, 5 PIPs, 1 Radius, 1 Ulna, 1 Wrist, 36.8ms
# Speed: 3.4ms preprocess, 36.8ms inference, 159.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
image_show("/content/drive/MyDrive/x_ray_detection/runs/detect/predict/1377_png_jpg.rf.7f7819891391b7db39229dd3724786df.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
# by using onix

# !yolo export model="/content/drive/MyDrive/x_ray_detection/runs/detect/train2/weights/best.pt" format=onnx
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11m summary (fused): 125 layers, 20,034,658 parameters, 0 gradients, 67.7 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/x_ray_detection/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 10, 8400) (38.6 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<1.18.0', 'onnxslim>=0.1.59', 'onnxruntime'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 3.0s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.64...
# ONNX: export success ✅ 8.1s, saved as '/content/drive/MyDrive/x_ray_detection/runs/detect/train2/weights/best.onnx' (76.7 MB)
#
# ...

# %%
# !yolo export model=yolo11n.pt format=engine
# Out:
# WARNING ⚠️ TensorRT requires GPU export, automatically assigning device=0
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo11n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.4 MB)
# requirements: Ultralytics requirement ['onnxruntime-gpu'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 3.2s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.64...
# ONNX: export success ✅ 4.9s, saved as 'yolo11n.onnx' (10.2 MB)
# requirements: Ultralytics requirement ['tensorrt>7.0.0,!=10.1.0'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 67.7s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ...

# %%
# by python usage
from ultralytics import YOLO

model = YOLO('yolo11n.pt')

results=model.train(data="/content/drive/MyDrive/x_ray_detection/data.yaml", epochs=1)
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model1 = YOLO("/content/drive/MyDrive/x_ray_detection/runs/detect/train3/weights/best.pt")
result=model1('/content/drive/MyDrive/x_ray_detection/train/images/1377_png_jpg.rf.7f7819891391b7db39229dd3724786df.jpg')
# Out:
# image 1/1 /content/drive/MyDrive/x_ray_detection/train/images/1377_png_jpg.rf.7f7819891391b7db39229dd3724786df.jpg: 640x640 4 DIPs, 5 MCPs, 5 PIPs, 1 Radius, 1 Ulna, 1 Wrist, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
